# %%
import matplotlib.pyplot as plt
import numpy as np




a1= [6.57285,6.86662,16.54600,21.61946,27.44002,26.33839,28.37824,32.46025,33.44923,38.20872,33.33558,30.87980,35.19739,32.85119,40.12939,
     40.69957,45.84828,33.77220,49.71782,50.80836,41.29664  ,36.14635  ,47.06047  ,57.82484  ,48.90583  ,43.39917  ,54.35755  ,34.74913  ,58.47192  ,43.36620  ,56.73868  ,55.69758  ,48.35153  ,44.18236  ,55.78700  ,40.66653  ,57.00790  ,40.75721  ,48.33815  ,60.27079  ,44.24472  ,44.23192  ,71.10838  
    ]

x = np.array([i*100 for i in range(len(a1))])
plt.plot(x,a1,label='Batch Data Revenue')
a2= [7.04073, 7.60444, 13.95607, 21.44250, 24.43663, 26.77082,  27.72524, 29.07341, 30.74037,  31.59354,  33.69569,  34.01079, 35.79889, 36.89556, 37.99628, 38.29590, 39.55817, 40.87961,  41.05730, 41.96249,  43.11830,  43.36968,  43.96731,  44.33858,  44.83126,  45.72465,  45.89643,  46.87427, 46.78535, 47.77685, 47.66330, 48.66745, 48.49636, 49.42551, 47.33033, 49.02036,  49.55374, 49.19686, 48.84094,  49.96891,  49.47281, 50.11296, 50.26551 ] 

print(len(a1),len(a2))

plt.plot(x,a2,label='Test Data Revenue')

plt.xlabel('Batches')
plt.ylabel('Revenue') 
plt.title('Training Revenue' )

plt.legend() 
plt.show()
# Out:
# 43 43
