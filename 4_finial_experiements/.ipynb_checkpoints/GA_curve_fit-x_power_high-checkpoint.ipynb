# %%
import math
import random
import torch
import numpy as np
import torch.nn.functional
import matplotlib.pyplot as plt
import torch.optim as opt
from torch.autograd import Variable
from sklearn.model_selection import train_test_split
import copy
import scipy.stats as st
from sklearn.datasets.samples_generator import make_blobs
from matplotlib.colors import LogNorm 
import matplotlib.cm as cm
import numpy as np, random, operator, pandas as pd, matplotlib.pyplot as plt
from collections import deque
import scipy
import time
# Out:
# D:\ComputerSoftwares\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
#print(np.sin(math.pi*1.5))

# %%
#global veriable 
Uniform_low_bound=0
Uniform_up_bound=1

number_of_groups=2

total_varible = 7
line_space = 101
Normal_loc=0.5
Normal_scale=0.2
Normal_loc1=0.3
Normal_loc2=0.7
Normal_scale1=0.1
Normal_scale2=0.1
Distribution_number=20000

# %%
popSize = 100
eliteSize = 20
mutationRate = 0.2
generations = 100
test_fitness_number = 200


global NeighborhoodRate
NeighborhoodRate = 0.1

# %%
Agent_number_n = agent_number_n = 2
seed = 7
np.random.seed(seed)
exec(open('../distribution1item_uniform.py').read())

X_train,  X_test = train_test_split(value_list, test_size=0.5, random_state=seed)

X_train=np.array(X_train)
X_test=np.array(X_test)
dataset_size = len(X_train)
print(dataset_size)
print(X_train[:100])
print(len(X_test))
# Out:
# [391.1958048    8.07743806]
# [[271.69199845  12.05608554]
#  [ 85.35414143   6.78185943]
#  [ 92.12115161   8.22734879]
#  ...
#  [303.15368136   3.59778968]
#  [191.24357187   7.38312562]
#  [163.77016144   3.63757603]]
# [271.69199845  85.35414143  92.12115161 ... 303.15368136 191.24357187
#  163.77016144]
# 100000
# [[3.10811920e+02 5.21631097e+00]
#  [8.61226170e-01 6.63691438e+00]
#  [2.95603823e+00 1.44399471e+01]
#  [4.93728627e+01 4.86427577e+00]
#  [2.62173548e+02 1.00846450e+00]
#  [1.40108567e+02 9.98630337e+00]
#  [4.59771295e+01 4.14795056e+00]
#  [2.78786783e+02 4.43510427e+00]
#  [1.09260416e+02 2.12982929e+00]
#  [3.74892787e+02 1.24830897e+00]
#  [4.35363480e+01 2.82198280e+00]
#  [3.51880012e+02 2.35325222e+00]
#  [1.29745097e+02 1.22779831e+01]
#  [3.20378740e+02 1.04930405e+00]
#  [2.00691820e+02 1.18857497e+01]
#  [1.78737319e+02 6.40578459e+00]
#  [2.83516693e+02 4.75052720e+00]
#  [1.50997313e+02 7.96806650e+00]
#  [1.40213013e+02 1.44715237e+00]
#  [3.51742787e+02 9.27805788e+00]
#  [2.78329570e+02 7.03372574e+00]
#  [1.51062135e+02 1.02240879e+00]
#  [2.86662452e+02 3.01750725e+00]
#  [5.87618795e+01 1.27603248e+00]
#  [9.61851227e+01 4.38462447e+00]
#  [3.28389184e+02 4.44544857e+00]
#  [3.04445294e+02 1.33037485e+01]
#  [1.98457112e+02 9.38581533e+00]
#  [3.01675273e+02 1.44465706e+01]
#  [1.05358945e+02 9.60916779e+00]
#  [1.15239025e+02 3.30060220e+00]
#  [1.68153447e+02 3.37068951e+00]
#  [1.35960931e+02 2.59272728e+00]
#  [3.48348493e+02 1.09486257e+01]
#  [1.27026195e+01 2.57897002e+00]
#  [1.90147542e+02 1.08218791e+00]
#  [6.87084630e+01 1.09173057e+01]
#  [1.41318493e+02 4.27312889e+00]
#  [9.74820537e+01 4.78208679e+00]
#  [2.92574840e+02 1.42636417e+01]
#  [3.92262780e+02 2.44442348e+00]
#  [6.11737017e+01 1.19715885e+01]
#  [1.41860473e+02 1.73687927e+00]
#  [6.86423188e+01 5.43330938e+00]
#  [7.68601249e+01 1.31854853e+01]
#  [3.91162240e+02 8.95316029e+00]
#  [9.34853613e+01 1.15138902e+00]
#  [3.80668101e+01 3.63677631e+00]
#  [8.11020152e+01 7.70844951e+00]
#  [1.97473976e+02 1.20343908e+01]
#  [3.62951087e+02 5.58386650e+00]
#  [1.50237093e+02 3.56934359e-01]
#  [7.33235119e+01 3.53645437e+00]
#  [7.96863422e+01 1.21727240e+01]
#  [1.34999317e+02 1.45217276e+01]
#  [7.74413126e+01 7.48647100e+00]
#  [8.17692650e+01 1.45199881e+01]
#  [1.96038084e+02 6.66427962e+00]
#  [3.27458781e+01 1.13795745e+01]
#  [2.97121438e+02 3.47953203e-02]
#  [3.87147562e+02 7.05359502e+00]
#  [1.51181639e+02 1.54013902e+00]
#  [2.03578265e+02 1.21182695e+01]
#  [3.59744253e+01 9.30021527e-01]
#  [3.60370403e+02 1.33627177e+01]
#  [1.31155375e+02 9.90580652e+00]
#  [1.01288213e+02 5.72111300e+00]
#  [3.95123726e+02 1.22014927e+01]
#  [4.54365509e+01 7.56668791e-01]
#  [3.76801625e+02 1.48149723e+01]
#  [1.67556176e+02 2.73477489e+00]
#  [1.01670674e+02 1.24614686e+00]
#  [5.46801829e+01 1.20074127e+01]
#  [2.02147975e+02 1.93697494e+00]
#  [1.53153178e+02 1.89975024e+00]
#  [3.56412056e+02 1.16353976e+01]
#  [3.79082085e+02 8.73060827e+00]
#  [2.23890849e+02 2.56846177e+00]
#  [2.87280019e+02 9.38251122e+00]
#  [1.00011041e+02 1.28655163e+01]
#  [9.68376118e+01 1.04602912e+01]
#  [3.88521601e+02 2.51239002e+00]
#  [2.14507461e+02 7.93322560e+00]
#  [3.67043747e+02 3.03592543e+00]
#  [3.92423264e+01 1.01931483e+01]
#  [9.79096925e+01 4.72645960e+00]
#  [9.95340001e+01 1.22104529e+00]
#  [9.05296926e+01 1.90009245e+00]
#  [1.60205364e+02 1.88555855e+00]
#  [3.44176897e+02 9.40242189e+00]
#  [3.07058894e+02 1.46419948e+01]
#  [1.82384375e+02 8.52628890e+00]
#  [2.51117870e+02 6.16918940e+00]
#  [1.31732726e+02 8.98338955e+00]
#  [2.05245778e+02 1.21855425e+01]
#  [1.74787607e+02 1.37238537e+01]
#  [1.96829885e+02 1.13384844e+01]
#  [9.68451220e+00 1.25769995e+01]
#  [3.24696629e+02 8.56967849e+00]
#  [7.91569189e+01 5.82658284e+00]]
# 100000

# %%
#S = [ 1, x, x^2, x^3,np.log(x), sinx, cosx, e^x ]
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import math

def func(x,a):
    return a[0] + a[1]*x + a[2]*(x** 2) +a[3]*(x** 3)+a[4]*(x** 4) + a[5]*(x**5) +a[6]*(x** 6)


# def funcc(x,a1,a2,a3,a4,a5,a6,a7,a8):
#     return a1 + a2*x + a3*(x** 2) +a4*(x** 3)++a[4]*(x** 4) +a5*np.sin(x) +a6*np.cos(x)  +a8* (np.exp(x))

# %%
#popt, pcov = curve_fit(funcc, xdata, ydata)
# print(popt)
# plt.xlabel('x')
# plt.ylabel('y')
# plt.legend()
# plt.show()

# %%
print( np.random.rand(total_varible)*np.random.randint(0,10))
# Out:
# [3.8490331  3.9256417  7.82423693 0.61964821 6.51818205 0.98851177
#  2.68313952]

# %%
x = np.linspace(0.0, 1, 100)
ao = func(x,np.random.rand(total_varible)*np.random.randint(0,10))
print(x)
print(ao)
# Out:
# [0.         0.01010101 0.02020202 0.03030303 0.04040404 0.05050505
#  0.06060606 0.07070707 0.08080808 0.09090909 0.1010101  0.11111111
#  0.12121212 0.13131313 0.14141414 0.15151515 0.16161616 0.17171717
#  0.18181818 0.19191919 0.2020202  0.21212121 0.22222222 0.23232323
#  0.24242424 0.25252525 0.26262626 0.27272727 0.28282828 0.29292929
#  0.3030303  0.31313131 0.32323232 0.33333333 0.34343434 0.35353535
#  0.36363636 0.37373737 0.38383838 0.39393939 0.4040404  0.41414141
#  0.42424242 0.43434343 0.44444444 0.45454545 0.46464646 0.47474747
#  0.48484848 0.49494949 0.50505051 0.51515152 0.52525253 0.53535354
#  0.54545455 0.55555556 0.56565657 0.57575758 0.58585859 0.5959596
#  0.60606061 0.61616162 0.62626263 0.63636364 0.64646465 0.65656566
#  0.66666667 0.67676768 0.68686869 0.6969697  0.70707071 0.71717172
#  0.72727273 0.73737374 0.74747475 0.75757576 0.76767677 0.77777778
#  0.78787879 0.7979798  0.80808081 0.81818182 0.82828283 0.83838384
#  0.84848485 0.85858586 0.86868687 0.87878788 0.88888889 0.8989899
#  0.90909091 0.91919192 0.92929293 0.93939394 0.94949495 0.95959596
#  0.96969697 0.97979798 0.98989899 1.        ]
# [0.47562862 0.47923836 0.48301064 0.48694826 0.49105401 0.49533074
#  0.49978132 0.50440867 0.50921577 0.51420565 0.51938144 0.52474633
#  0.53030363 0.53605673 0.54200919 0.54816465 0.55452694 0.56110004
#  0.5678881  0.57489549 0.58212677 0.58958673 0.59728041 0.6052131
#  0.61339041 0.6218182  0.63050268 0.6394504  0.64866826 0.65816355
#  0.66794397 0.67801763 0.68839311 0.69907945 0.71008621 0.72142345
#  0.73310178 0.74513241 0.75752713 0.77029836 0.7834592  0.7970234
#  0.81100545 0.82542058 0.84028479 0.85561489 0.87142852 0.8877442
#  0.90458133 0.92196027 0.93990234 0.95842984 0.97756614 0.99733566
#  1.01776394 1.03887765 1.06070466 1.08327405 1.10661616 1.13076263
#  1.15574643 1.18160192 1.20836485 1.23607247 1.26476348 1.29447817
#  1.32525839 1.35714762 1.39019103 1.42443549 1.45992963 1.49672392
#  1.53487066 1.57442405 1.61544025 1.65797744 1.7020958  1.74785765
#  1.79532744 1.84457182 1.89565968 1.94866222 2.003653   2.06070798
#  2.11990556 2.18132669 2.24505485 2.31117618 2.37977947 2.45095626
#  2.52480088 2.60141051 2.68088523 2.7633281  2.8488452  2.93754569
#  3.0295419  3.12494934 3.22388679 3.32647639]

# %%
def valuation(type_offender, type_defender, t):
    v_1 = type_offender * (t - t ** 2 / 2)
    v_2 = type_defender * (1 - t)
    
    return v_1, v_2



class individual:
    def __init__(self, function_list,u_offender,u_defender):
        self.function_list = function_list
        self.u_offender = u_offender
        self.u_defender = u_defender
        self.fitness = -1
        self.average_revenue = 0.0
        self.Z_payment_list = []
        self.Z_o_star_list = []
    def Fitness(self):
        if(self.fitness!=-1 and random.random()>NeighborhoodRate):
            return self
        x = np.linspace(0, 1, line_space)
        #print(x)
        test_number = 0
        ao = func(x,self.function_list)
        total_payment = 0
        #print(ao)
#         for index in range(len(X_train)):
#             test_number+=1
#             type_offender = X_train[index][0]
#             type_defender = X_train[index][1]
        for ran in range(test_fitness_number):
            test_number+=1
            index = random.randint(0,len(X_train)-1)
            type_offender = X_train[index][0]
            type_defender = X_train[index][1]
            
      
            
            value_offender, value_defender = valuation(
                type_offender, type_defender, x)
            temp_val_offender = (value_offender * (self.u_offender))
            temp_val_defender = (value_defender * (self.u_defender))

            val_offender = temp_val_offender + ao
            val_defender = temp_val_defender + ao
            # print(o.grad_fn,temp_val_defender.grad_fn)
            
            #print(val_offender)

            max_offender = max(val_offender)
            max_defender = max(val_defender)

            #print("max_offender: " ,max_offender,max_offender.grad)

            val_sum = val_offender + val_defender - ao
            t_end = val_sum.tolist().index(max(val_sum))

            end_val_offender = val_offender[int(t_end)]
            end_val_defender = val_defender[int(t_end)]
            pay_offender = (max_defender - end_val_defender) / \
                (self.u_offender)
            pay_defender = (max_offender - end_val_offender) / \
                (self.u_defender)

    #         if((max_defender - end_val_defender) / self.u_offender > value_offender[int(t_end)]):
    #             print("error: payment offender",(max_defender - end_val_defender) / self.u_offender,value_offender[int(t_end)]);
    #         if((max_offender - end_val_offender) / self.u_defender > value_defender[int(t_end)]):
    #             print("error: payment defender",(max_offender - end_val_offender) / self.u_defender,value_defender[int(t_end)]);

            payment = pay_offender + pay_defender
            total_payment = total_payment + payment
        self.fitness = total_payment/test_number
    #    self.average_revenue = total_payment/test_number
        #return payment, ao, x[int(t_end)], self.u_offender, self.u_defender   
        return self

    def Train_Fitness(self):
        x = np.linspace(0, 1, line_space)
        #print(x)
        test_number = 0
        ao = func(x,self.function_list)
        total_payment = 0
        #print(ao)
        for index in range(len(X_train)):
            test_number+=1
            type_offender = X_train[index][0]
            type_defender = X_train[index][1]
#         for ran in range(test_fitness_number):
#             test_number+=1
#             index = random.randint(0,len(X_train)-1)
#             type_offender = X_train[index][0]
#             type_defender = X_train[index][1]
            
      
            
            value_offender, value_defender = valuation(
                type_offender, type_defender, x)
            temp_val_offender = (value_offender * (self.u_offender))
            temp_val_defender = (value_defender * (self.u_defender))

            val_offender = temp_val_offender + ao
            val_defender = temp_val_defender + ao
            # print(o.grad_fn,temp_val_defender.grad_fn)
            
            #print(val_offender)

            max_offender = max(val_offender)
            max_defender = max(val_defender)

            #print("max_offender: " ,max_offender,max_offender.grad)

            val_sum = val_offender + val_defender - ao
            t_end = val_sum.tolist().index(max(val_sum))

            end_val_offender = val_offender[int(t_end)]
            end_val_defender = val_defender[int(t_end)]
            pay_offender = (max_defender - end_val_defender) / \
                (self.u_offender)
            pay_defender = (max_offender - end_val_offender) / \
                (self.u_defender)

    #         if((max_defender - end_val_defender) / self.u_offender > value_offender[int(t_end)]):
    #             print("error: payment offender",(max_defender - end_val_defender) / self.u_offender,value_offender[int(t_end)]);
    #         if((max_offender - end_val_offender) / self.u_defender > value_defender[int(t_end)]):
    #             print("error: payment defender",(max_offender - end_val_offender) / self.u_defender,value_defender[int(t_end)]);

            payment = pay_offender + pay_defender
            total_payment = total_payment + payment
        self.fitness = total_payment/test_number
    #    self.average_revenue = total_payment/test_number
        #return payment, ao, x[int(t_end)], self.u_offender, self.u_defender   
        return self
    
    def Test_Fitness(self):
        x = np.linspace(0, 1, line_space)
        #print(x)
        test_number = 0
        ao = func(x,self.function_list)
        #print(ao)
        total_payment = 0
        self.Z_payment_list = []
        self.Z_o_star_list = []
        for index in range(len(X_test)):
            test_number+=1
            type_offender = X_test[index][0]
            type_defender = X_test[index][1]
#         for ran in range(test_fitness_number):
#             test_number+=1
#             index = random.randint(0,len(X_train)-1)
#             type_offender = X_train[index][0]
#             type_defender = X_train[index][1]
            
      
            
            value_offender, value_defender = valuation(
                type_offender, type_defender, x)
            temp_val_offender = (value_offender * (self.u_offender))
            temp_val_defender = (value_defender * (self.u_defender))

            val_offender = temp_val_offender + ao
            val_defender = temp_val_defender + ao
            # print(o.grad_fn,temp_val_defender.grad_fn)
            
            #print(val_offender)

            max_offender = max(val_offender)
            max_defender = max(val_defender)

            #print("max_offender: " ,max_offender,max_offender.grad)

            val_sum = val_offender + val_defender - ao
            t_end = val_sum.tolist().index(max(val_sum))

            end_val_offender = val_offender[int(t_end)]
            end_val_defender = val_defender[int(t_end)]
            pay_offender = (max_defender - end_val_defender) / \
                (self.u_offender)
            pay_defender = (max_offender - end_val_offender) / \
                (self.u_defender)

    #         if((max_defender - end_val_defender) / self.u_offender > value_offender[int(t_end)]):
    #             print("error: payment offender",(max_defender - end_val_defender) / self.u_offender,value_offender[int(t_end)]);
    #         if((max_offender - end_val_offender) / self.u_defender > value_defender[int(t_end)]):
    #             print("error: payment defender",(max_offender - end_val_offender) / self.u_defender,value_defender[int(t_end)]);

            payment = pay_offender + pay_defender
            total_payment = total_payment + payment
            
            self.Z_payment_list.append(payment)
            self.Z_o_star_list.append(x[int(t_end)])
        #return payment, ao, x[int(t_end)], self.u_offender, self.u_defender 
        self.average_revenue = total_payment/test_number
        return self
    
    def debug(self):
        print("function_list: ",self.function_list)
        print("Batch_fitness",self.fitness)
        self.Train_Fitness()
        print("Train_fitness",self.fitness)
        self.Test_Fitness()
        print("Test_average_revenue",self.average_revenue)
        print("u_offender",self.u_offender)
        print("u_defender",self.u_defender)
        print()

# %%
global population 



def rank_heads(population):
    fitnessResults = []
    for i in range(0,len(population)):
        temp = population[i].Fitness()
        fitnessResults.append([i,  temp.fitness, temp])
    fitnessResults = np.array(fitnessResults)
    
    return sorted(fitnessResults, key = operator.itemgetter(1), reverse=True)

def rank_heads_all(population):
    fitnessResults = []
    for i in range(0,len(population)):
        temp = population[i].Test_Fitness()
        fitnessResults.append([i, temp.fitness, temp])
    fitnessResults = np.array(fitnessResults)
    
    return sorted(fitnessResults, key = operator.itemgetter(1), reverse=True)


def initialPopulation():
    population = []
    for i in range(popSize):
        temp_a = np.random.rand(total_varible)*np.random.randint(-100,100)
        for j in range(total_varible):
            temp_a[j] /=(j+1)
        temp_b = 1
        temp_c = 3.7#random.random()*np.random.randint(1,10)
        
        temp = individual(temp_a,temp_b,temp_c)
        temp.Fitness()
        population.append(temp)
    return population

pop = np.array(initialPopulation())
pop[0].debug()
pop[10].debug()

pop_ranked = rank_heads(pop)

pop_ranked[0][2].debug()
pop_ranked[10][2].debug()
# Out:
# function_list:  [86.23744475 30.67654455 11.07037543  5.29378813 10.36556276  3.47062197
#   0.25885462]
# Batch_fitness 0.0
# Train_fitness 0.0
# Test_average_revenue 0.0
# u_offender 1
# u_defender 3.7
#
# function_list:  [ -4.24400377 -28.31320687 -14.58963284  -7.14379562  -4.37993649
#   -9.91865477  -2.03791692]
# Batch_fitness 32.699280039447565
# Train_fitness 32.24993203749545
# Test_average_revenue 32.43632524110048
# u_offender 1
# u_defender 3.7
#
# function_list:  [ -6.23511404 -28.80202613 -23.96651404 -15.91423385  -7.7169068
#   -5.33904105 -11.46731869]
# Batch_fitness 33.10957987810843
# Train_fitness 31.801913832899242
# Test_average_revenue 32.006245853385074
# u_offender 1
# u_defender 3.7
#
# function_list:  [-62.58427958 -30.59854426 -19.66102498  -2.96960089  -7.34384854
#  -10.20793185  -1.44471568]
# Batch_fitness 30.385328261248475
# Train_fitness 32.81501488616956
# Test_average_revenue 33.0186203361442
# u_offender 1
# u_defender 3.7

# %%
xdata = np.linspace(0, 1, 100)
ydata = func(xdata,pop_ranked[0][2].function_list)
plt.plot(xdata,ydata,label='a(t)')

plt.xlabel('t')
plt.ylabel('a(t)') 
plt.title('a(t)')

plt.legend() 
plt.show()

# %%
def selection(popRanked, eliteSize):
    selectionResults = []
    df = pd.DataFrame(np.array(popRanked), columns=["Index","Fitness","list"])
    df['cum_sum'] = df.Fitness.cumsum()
    df['cum_perc'] = 100*df.cum_sum/df.Fitness.sum()
    
    for i in range(int(len(popRanked))):
        selectionResults.append(popRanked[i][0])
    return selectionResults

def matingPool(population, selectionResults):
    matingpool = []
    for i in range(0, len(selectionResults)):
        index = selectionResults[i]
        matingpool.append(population[index])
    return matingpool

def breed(parent1, parent2):
    child = copy.deepcopy(parent1)
    
    geneA_1 = int(random.random() * len(parent1.function_list))
    geneB_1 = int(random.random() * len(parent1.function_list))
    startGene_1 = min(geneA_1, geneB_1)
    endGene_1 = max(geneA_1, geneB_1)
    
#     geneA_2 = int(random.random() * len(parent2.function_list))
#     geneB_2 = int(random.random() * len(parent2.function_list))
#     startGene_2 = min(geneA_2, geneB_2)
#     endGene_2 = max(geneA_2, geneB_2)
    
    child.function_list = []

    for i in range(startGene_1):
        child.function_list.append(parent1.function_list[i])

        
    for i in range(startGene_1,endGene_1):
        child.function_list.append(parent2.function_list[i])
        
    for i in range(endGene_1, len(parent1.function_list)):
        child.function_list.append(parent1.function_list[i])
        
    #print(len(child.function_list))
    child.fitness = -1;
    return child
#     if   non_dominant(child):
#         child.fitness = 0;
#         return child
#     else:
#         return False 

def breedPopulation(matingpool, eliteSize):
    children = []
    length = len(matingpool) - eliteSize
    pool = random.sample(matingpool, len(matingpool))

    for i in range(eliteSize):
        children.append(matingpool[i])

    for i in range(popSize):
        if (random.random() < mutationRate):
            swapped = copy.deepcopy(pool[random.randint(0,len(matingpool)-1)])
            swapWith = copy.deepcopy(pool[random.randint(0,len(matingpool)-1)])
            
            for j in range(len(swapWith.function_list)):
                swapped.function_list[j]=swapWith.function_list[j]
            
#             if (non_dominant(swapped)):
            if(random.random()>0.5):
                swapped.u_offender = swapWith.u_offender
            if(random.random()>0.5):
                swapped.u_defender = swapWith.u_defender
            swapped.fitness = -1
            children.append(swapped)

    for i in range(popSize):
        if (random.random() < mutationRate):
            child = breed(pool[random.randint(0,len(matingpool)-1)], pool[random.randint(0,len(matingpool)-1)])
            if (child != False):
                child.fitness = -1
                children.append(child)
    
    return children

# %%
def mutate(individual, mutationRate):
    global NeighborhoodRate 
    
    temp_individual = copy.deepcopy(individual)

    for nerboorhood in range(len(temp_individual.function_list)):
        if(random.random() < NeighborhoodRate):
            if(random.random()>=0.5):
                temp_individual.function_list[nerboorhood]+= 0.1
            else:
                temp_individual.function_list[nerboorhood]-= 0.1
            temp_individual.fitness= -1          
            
        if(random.random() < NeighborhoodRate):  
            if(random.random()>=0.5):
                temp_individual.u_defender += 0.01
            else:
                temp_individual.u_defender -= 0.01
            temp_individual.fitness= -1   
            
    if(temp_individual.Fitness().fitness<individual.Fitness().fitness):
        individual = temp_individual
        
    return individual

# %%
def mutatePopulation(population, mutationRate):
    mutatedPop = []

    for ind in range(0, len(population)):
        mutatedInd = mutate(copy.deepcopy(population[ind]), mutationRate)
        mutatedPop.append(mutatedInd)
    return mutatedPop

# %%
def nextGeneration(currentGen, eliteSize, mutationRate):
    print(len(currentGen))
    popRanked = rank_heads(currentGen)

    selectionResults = selection(popRanked, eliteSize)
    
    matingpool = matingPool(currentGen, selectionResults)

    children = breedPopulation(matingpool, eliteSize)

    nextGeneration = mutatePopulation(children, mutationRate)

#     for i in range(len(nextGeneration), popSize):
#         nextGeneration.append( produce_initial_head_list())

    return nextGeneration
temp_a = np.array(rank_heads(pop))
#print(temp_a )

# %%
final_pop =[]
batch_err_list = []
train_err_list = []  
test_err_list = [] 
best_list = []
def geneticAlgorithm(pop, popSize, eliteSize, mutationRate, generations):

    print("Initial Delay: " + str(rank_heads(pop)[0][1]))
    best_Index = rank_heads(pop)[0][0]
    best_one = pop[best_Index]
    best_one.debug()
    progress = []
    progress.append(rank_heads(pop)[0][1])
    
    for i in range(0, generations):
        pop = nextGeneration(pop, eliteSize, mutationRate)
        print("Generation " , i , " : " + str(rank_heads(pop)[0][1]))
        progress.append(rank_heads(pop)[0][1])
        best_Index = rank_heads(pop)[0][0]
        best_one = pop[best_Index]
        batch_err_list.append(best_one.fitness)
        best_one.debug()
        best_list.append(best_one)
        train_err_list.append(best_one.fitness)
        test_err_list.append(best_one.average_revenue)
        final_pop.append(pop[best_Index])
        print()
        
#     for i in range (len(pop)):
#         final_pop.append(pop[i])
    
    res_rank = rank_heads_all(final_pop)
    
    bestdeadlineIndex = res_rank[0][0]
    bestdeadline = final_pop[bestdeadlineIndex]

    print("Final Delay: " + str(res_rank[0][1]))
        
    #print(progress)
    plt.plot(progress)
    plt.ylabel('Delay')
    plt.xlabel('Generation')
    plt.show()
    return bestdeadline

# %%
result = geneticAlgorithm(pop, popSize, eliteSize, mutationRate, generations)
# Out:
# Initial Delay: 33.78481230093164
# function_list:  [ -4.24400377 -28.31320687 -14.58963284  -7.14379562  -4.37993649
#   -9.91865477  -2.03791692]
# Batch_fitness 33.78481230093164
# Train_fitness 32.24993203749545
# Test_average_revenue 32.43632524110048
# u_offender 1
# u_defender 3.7
#
# 100
# Generation  0  : 35.145353939964046
# function_list:  [-21.7503539  -28.12578198 -11.51023688  -1.52164238  -2.85750651
#   -0.239858    -5.43617007]
# Batch_fitness 35.145353939964046
# Train_fitness 32.75167077964022
# Test_average_revenue 32.92762931935715
# u_offender 1
# u_defender 3.7
#
#
# 60
# Generation  1  : 34.09134040727361
# function_list:  [-62.58427958 -30.59854426 -19.66102498  -2.96960089  -7.34384854
#  -10.20793185  -1.44471568]
# Batch_fitness 34.17330676533152
# Train_fitness 32.81501488616956
# Test_average_revenue 33.0186203361442
# u_offender 1
# u_defender 3.7
#
#
# 60
# Generation  2  : 35.213724197354104
# function_list:  [ -2.35459201 -26.28407614 -11.16265306  -0.13745807  -9.5509916
#   -3.90291471  -0.10378355]
# Batch_fitness 35.01534043674576
# Train_fitness 32.05795332223119
# Test_average_revenue 32.225792020871815
# u_offender 1
# u_defender 3.7
#
#
# 60
# Generation  3  : 35.112269803606004
# function_list:  [-91.38139068693962, -39.031996990131454, 5.877512449658136, 4.676029786523793, -6.2802160881598335, -0.5072315022110357, -6.41165818134906]
# Batch_fitness 36.37239446001797
# Train_fitness 34.04034983529318
# Test_average_revenue 34.20956979864305
# u_offender 1
# u_defender 3.6800000000000006
#
#
#
# u_offender 1
# u_defender 3.6800000000000006
#
#
# 58
# Generation  14  : 38.25559835600956
# function_list:  [-91.38139068693962, -39.131996990131455, 3.145114185416659, 1.6612300366828512, 5.18936954307035, 4.875730660792755, 1.7476604733552]
# Batch_fitness 38.25559835600956
# Train_fitness 35.485944894759996
# Test_average_revenue 35.63301705735678
# u_offender 1
# u_defender 3.71
#
#
# 60
# Generation  15  : 38.1588260111798
# function_list:  [-91.38139068693962, -39.131996990131455, -6.023102190174865, 4.576029786523794, 6.430189493532149, 4.875730660792755, 1.7476604733552]
# Batch_fitness 38.94843455849841
# Train_fitness 36.90425285739976
# Test_average_revenue 37.096606595084474
# u_offender 1
# u_defender 3.6800000000000006
#
#
# 63
# Generation  16  : 38.282510648955714
# function_list:  [-91.38139068693962, -39.031996990131454, 3.245114185416659, 1.561230036682851, 5.18936954307035, 4.975730660792754, 1.6476604733551998]
# Batch_fitness 38.69864911796388
# Train_fitness 35.30555064409617
# Test_average_revenue 35.44751479950521
# u_offender 1
# u_defender 3.6500000000000012
#
#
# 58
# Generation  17  : 38.58164958411447
# function_list:  [-91.28139068693963, -39.131996990131455, -6.023102190174865, 4.576029786523794, 6.430189493532149, 4.875730660792755, 1.7476604733552]
# Batch_fitness 38.87253746738233
# Train_fitness 36.94005982500857
# Test_average_revenue 37.132001009351505
# u_offender 1
# u_defender 3.7
#
#
# 55
# Generation  18  : 37.62596022739915
# function_list:  [-91.48139068693962, -39.131996990131455, -6.023102190174865, 4.576029786523794, 6.430189493532149, 4.775730660792755, 1.7476604733552]
# Batch_fitness 37.97089082991438
# Train_fitness 36.928388470579705
# Test_average_revenue 37.12057411812246
# u_offender 1
# u_defender 3.6900000000000004
#
#
# 71
# Generation  19  : 38.38411528220449
# function_list:  [-91.28139068693963, -39.031996990131454, -6.023102190174865, 4.576029786523794, 6.430189493532149, 4.875730660792755, 1.7476604733552]
# Batch_fitness 39.49430417889475
# Train_fitness 36.90816345792426
# Test_average_revenue 37.10007928080188
# u_offender 1
# u_defender 3.7
#
#
# 59
# Generation  20  : 38.07266615102744
# function_list:  [-91.38139068693962, -39.131996990131455, -6.023102190174865, 4.576029786523794, 6.430189493532149, 4.875730660792755, 1.6476604733551998]
# Batch_fitness 39.00344039261668
# Train_fitness 36.85564042237629
# Test_average_revenue 37.04549671503001
# u_offender 1
# u_defender 3.6500000000000012
#
#
# 61
# Generation  21  : 38.24270553200501
# function_list:  [-91.48139068693962, -39.131996990131455, -6.023102190174865, 4.576029786523794, 6.430189493532149, 4.775730660792755, 1.7476604733552]
# Batch_fitness 38.808135363343496
# Train_fitness 36.928388470579705
# Test_average_revenue 37.12057411812246
# u_offender 1
# u_defender 3.6900000000000004
#
#
# 58
# Generation  22  : 40.26880891363447
# function_list:  [-91.48139068693962, -39.131996990131455, -6.023102190174865, 4.576029786523794, 6.430189493532149, 4.775730660792755, 1.7476604733552]
# Batch_fitness 41.48238443939327
# Train_fitness 36.91043271619252
# Test_average_revenue 37.102563624752456
# u_offender 1
# u_defender 3.6800000000000006
#
#
# 58
# Generation  23  : 39.124774521002166
# function_list:  [-91.48139068693962, -39.131996990131455, -6.023102190174865, 4.576029786523794, 6.430189493532149, 4.975730660792754, 1.7476604733552]
# Batch_fitness 39.124774521002166
# Train_fitness 36.917001228987495
# Test_average_revenue 37.107874640864885
# u_offender 1
# u_defender 3.6900000000000004
#
#
# 56
# Generation  24  : 40.45962725051998
# function_list:  [-91.48139068693962, -39.131996990131455, -6.023102190174865, 4.576029786523794, 6.430189493532149, 4.975730660792754, 1.7476604733552]
# Batch_fitness 40.45962725051998
# Train_fitness 36.917001228987495
# Test_average_revenue 37.107874640864885
# u_offender 1
# u_defender 3.6900000000000004
#
#
# 60
# Generation  25  : 38.86904740947077
# function_list:  [-91.58139068693961, -39.131996990131455, -6.123102190174865, 4.576029786523794, 6.430189493532149, 4.875730660792755, 1.8476604733552]
# Batch_fitness 39.34205995272374
# Train_fitness 36.95468463771657
# Test_average_revenue 37.147693808379856
# u_offender 1
# u_defender 3.7
#
#
# 67
# Generation  26  : 38.654860983659034
# function_list:  [-91.28139068693963, -39.131996990131455, -6.023102190174865, 1.6612300366828512, 6.430189493532149, 4.775730660792755, 1.8476604733552]
# Batch_fitness 38.654860983659034
# Train_fitness 37.15633196626487
# Test_average_revenue 37.362123428428575
# u_offender 1
# u_defender 3.71
#
#
# 68
# Generation  27  : 39.93110765894411
# function_list:  [-91.58139068693961, -39.131996990131455, -6.023102190174865, 4.476029786523794, 6.430189493532149, 4.975730660792754, 1.7476604733552]
# Batch_fitness 39.93110765894411
# Train_fitness 36.91096328780165
# Test_average_revenue 37.10339911169508
# u_offender 1
# u_defender 3.6800000000000006
#
#
#
 4.875730660792755, 1.5476604733551997]
# Batch_fitness 40.15626488904951
# Train_fitness 37.10143123298689
# Test_average_revenue 37.30724313902113
# u_offender 1
# u_defender 3.6900000000000004
#
#
# 57
# Generation  48  : 39.93272060982204
# function_list:  [-91.48139068693962, -39.031996990131454, -6.123102190174865, 1.6612300366828512, 6.430189493532149, 4.875730660792755, 1.6476604733551998]
# Batch_fitness 40.23109330430935
# Train_fitness 37.0687384081197
# Test_average_revenue 37.27518337564823
# u_offender 1
# u_defender 3.670000000000001
#
#
# 65
# Generation  49  : 39.63728315875159
# function_list:  [-91.58139068693961, -39.23199699013146, -6.123102190174865, 1.6612300366828512, 6.430189493532149, 4.875730660792755, 1.4476604733551997]
# Batch_fitness 39.63728315875159
# Train_fitness 37.10502281600393
# Test_average_revenue 37.31332367908897
# u_offender 1
# u_defender 3.670000000000001
#
#
# 62
# Generation  50  : 40.01892889429143
# function_list:  [-91.28139068693963, -39.131996990131455, -5.923102190174865, 4.3760297865237945, 6.430189493532149, 4.875730660792755, 1.5476604733551997]
# Batch_fitness 40.77639527514932
# Train_fitness 36.95075199296781
# Test_average_revenue 37.142891907952766
# u_offender 1
# u_defender 3.7
#
#
# 59
# Generation  51  : 40.01892889429143
# function_list:  [-91.38139068693962, -38.93199699013145, -6.123102190174865, 1.7612300366828513, 6.5301894935321485, 4.775730660792755, 1.5476604733551997]
# Batch_fitness 40.01892889429143
# Train_fitness 37.043670844492326
# Test_average_revenue 37.249685481865185
# u_offender 1
# u_defender 3.6800000000000006
#
#
# 57
# Generation  52  : 39.778569313847825
# function_list:  [-91.48139068693962, -39.23199699013146, -6.123102190174865, 4.576029786523794, 6.430189493532149, 4.875730660792755, 1.8476604733552]
# Batch_fitness 39.778569313847825
# Train_fitness 37.020523087620724
# Test_average_revenue 37.2143501026272
# u_offender 1
# u_defender 3.7199999999999998
#
#
# 62
# Generation  53  : 40.12924711222858
# function_list:  [-91.28139068693963, -39.33199699013146, -6.223102190174864, 1.461230036682851, 6.430189493532149, 4.775730660792755, 1.9476604733552]
# Batch_fitness 40.12924711222858
# Train_fitness 37.196894845546815
# Test_average_revenue 37.40590653674761
# u_offender 1
# u_defender 3.6800000000000006
#
#
# 64
# Generation  54  : 38.76564645567933
# function_list:  [-91.18139068693964, -38.93199699013145, -6.123102190174865, 4.476029786523794, 6.5301894935321485, 4.875730660792755, 1.6476604733551998]
# Batch_fitness 38.76564645567933
# Train_fitness 36.75911561159258
# Test_average_revenue 36.94930819327886
# u_offender 1
# u_defender 3.620000000000002
#
#
# 49
# Generation  55  : 38.57192543538176
# function_list:  [-91.28139068693963, -39.33199699013146, -6.223102190174864, 1.7612300366828513, 6.5301894935321485, 4.875730660792755, 1.5476604733551997]
# Batch_fitness 39.517130953060075
# Train_fitness 37.272619264288146
# Test_average_revenue 37.48342973011111
# u_offender 1
# u_defender 3.749999999999999
#
#
# 48
# Generation  56  : 38.820813686348096
# function_list:  [-91.38139068693962, -39.031996990131454, -6.223102190174864, 1.461230036682851, 6.430189493532149, 4.775730660792755, 1.8476604733552]
# Batch_fitness 39.22555443757203
# Train_fitness 37.10861596652042
# Test_average_revenue 37.31645163407742
# u_offender 1
# u_defender 3.6800000000000006
#
#
#
 4.875730660792755, 1.5476604733551997]
# Batch_fitness 40.217339837941054
# Train_fitness 36.95623999031606
# Test_average_revenue 37.1496871641328
# u_offender 1
# u_defender 3.7299999999999995
#
#
# 58
# Generation  69  : 39.534040793576445
# function_list:  [-91.18139068693964, -39.33199699013146, -6.223102190174864, 1.6612300366828512, 6.5301894935321485, 4.775730660792755, 1.9476604733552]
# Batch_fitness 39.9624841974807
# Train_fitness 37.180488601301924
# Test_average_revenue 37.387868657520585
# u_offender 1
# u_defender 3.670000000000001
#
#
# 59
# Generation  70  : 37.74224021323543
# function_list:  [-91.18139068693964, -39.33199699013146, -6.223102190174864, 1.6612300366828512, 6.5301894935321485, 4.775730660792755, 1.9476604733552]
# Batch_fitness 39.01977657401189
# Train_fitness 37.180488601301924
# Test_average_revenue 37.387868657520585
# u_offender 1
# u_defender 3.670000000000001
#
#
# 53
# Generation  71  : 40.35129249998115
# function_list:  [-91.28139068693963, -39.131996990131455, -5.923102190174865, 4.576029786523794, 6.330189493532149, 4.875730660792755, 1.4476604733551997]
# Batch_fitness 40.12513069137448
# Train_fitness 36.973200898424054
# Test_average_revenue 37.16541104002478
# u_offender 1
# u_defender 3.7199999999999998
#
#
# 56
# Generation  72  : 40.46282118264271
# function_list:  [-91.38139068693962, -39.131996990131455, -6.123102190174865, 1.7612300366828513, 6.5301894935321485, 4.875730660792755, 1.6476604733551998]
# Batch_fitness 40.46282118264271
# Train_fitness 37.17298523959653
# Test_average_revenue 37.37981700072581
# u_offender 1
# u_defender 3.7199999999999998
#
#
# 53
# Generation  73  : 39.29755971183702
# function_list:  [-91.18139068693964, -39.031996990131454, -6.223102190174864, 1.6612300366828512, 6.5301894935321485, 4.775730660792755, 1.9476604733552]
# Batch_fitness 39.29755971183702
# Train_fitness 37.13057887664084
# Test_average_revenue 37.334695591728476
# u_offender 1
# u_defender 3.6900000000000004
#
#
# 64
# Generation  74  : 38.93310108727008
# function_list:  [-91.38139068693962, -39.031996990131454, -6.123102190174865, 1.6612300366828512, 6.13018949353215, 4.575730660792756, 1.4476604733551997]
# Batch_fitness 39.12810699465473
# Train_fitness 36.983430469149006
# Test_average_revenue 37.18886025802951
# u_offender 1
# u_defender 3.6500000000000012
#
#
# 54
# Generation  75  : 38.662996641855116
# function_list:  [-91.38139068693962, -39.23199699013146, -6.123102190174865, 4.576029786523794, 6.330189493532149, 4.875730660792755, 2.0476604733552]
# Batch_fitness 39.10923195008318
# Train_fitness 36.98659342471912
# Test_average_revenue 37.179032571982425
# u_offender 1
# u_defender 3.7
#
#
# 56
# Generation  76  : 39.271874924242645
# function_list:  [-91.18139068693964, -39.031996990131454, -5.923102190174865, 1.6612300366828512, 6.5301894935321485, 4.775730660792755, 1.9476604733552]
# Batch_fitness 41.332802045274974
# Train_fitness 37.06272430981849
# Test_average_revenue 37.2676952671588
# u_offender 1
# u_defender 3.670000000000001
#
#
# 54
# Generation  77  : 40.26137238725038
# function_list:  [-91.28139068693963, -39.031996990131454, -6.223102190174864, 1.6612300366828512, 6.430189493532149, 4.775730660792755, 1.9476604733551999]
# Batch_fitness 40.26137238725038
# Train_fitness 37.127899175648906
# Test_average_revenue 37.33366084061222
# u_offender 1
# u_defender 3.6900000000000004
#
#
# 56
# Generation  78  : 39.03959306991069
# function_list:  [-91.18139068693964, -38.93199699013145, -6.023102190174865, 1.6612300366828512, 6.5301894935321485, 4.775730660792755, 1.9476604733552]
# Batch_fitness 39.03959306991069
# Train_fitness 37.03118376202864
# Test_average_revenue 37.23558143401382
# u_offender 1
# u_defender 3.660000000000001
#
#
# 55
# Generation  79  : 40.3331213936788
# function_list:  [-91.18139068693964, -38.93199699013145, -6.023102190174865, 1.6612300366828512, 6.5301894935321485, 4.775730660792755, 1.9476604733552]
# Batch_fitness 39.65239904357982
# Train_fitness 37.03118376202864
# Test_average_revenue 37.23558143401382
# u_offender 1
# u_defender 3.660000000000001
#
#
# 58
# Generation  80  : 39.3430723628983
# function_list:  [-91.18139068693964, -39.131996990131455, -5.923102190174865, 1.6612300366828512, 6.430189493532149, 4.875730660792755, 1.4476604733551997]
# Batch_fitness 39.4657535283978
# Train_fitness 37.074327728358945
# Test_average_revenue 37.27985566222047
# u_offender 1
# u_defender 3.6800000000000006
#
#
# 56
# Generation  81  : 38.64163437956063
# function_list:  [-91.28139068693963, -39.131996990131455, -5.923102190174865, 1.7612300366828513, 6.5301894935321485, 4.875730660792755, 2.0476604733552]
# Batch_fitness 38.64163437956063
# Train_fitness 37.047953670744484
# Test_average_revenue 37.251920399286334
# u_offender 1
# u_defender 3.6400000000000015
#
#
# 59
# Generation  82  : 39.63080151819242
# function_list:  [-91.38139068693962, -39.33199699013146, -6.123102190174865, 1.7612300366828513, 6.330189493532149, 4.775730660792755, 2.1476604733552]
# Batch_fitness 40.514096694896764
# Train_fitness 37.250756109962005
# Test_average_revenue 37.459654305937995
# u_offender 1
# u_defender 3.7199999999999998
#
#
# 70
# Generation  83  : 39.16220750567721
# function_list:  [-91.38139068693962, -39.031996990131454, -6.223102190174864, 1.6612300366828512, 6.430189493532149, 4.775730660792755, 1.4476604733551997]
# Batch_fitness 40.66569936155934
# Train_fitness 37.144038662516316
# Test_average_revenue 37.352781103187944
# u_offender 1
# u_defender 3.7299999999999995
#
#
# 59
# Generation  84  : 39.06351998455168
# function_list:  [-91.38139068693962, -39.131996990131455, -6.123102190174865, 1.561230036682851, 6.5301894935321485, 4.875730660792755, 1.6476604733551998]
# Batch_fitness 39.06351998455168
# Train_fitness 37.20597212659827
# Test_average_revenue 37.41558674882944
# u_offender 1
# u_defender 3.7399999999999993
#
#
# 73
# Generation  85  : 38.57757997982294
# function_list:  [-91.38139068693962, -39.43199699013146, -6.123102190174865, 4.476029786523794, 6.430189493532149, 4.875730660792755, 1.9476604733552]
# Batch_fitness 38.80376928731934
# Train_fitness 37.02305869208464
# Test_average_revenue 37.21697784986366
# u_offender 1
# u_defender 3.6800000000000006
#
#
# 67
# Generation  86  : 39.1046974402833
# function_list:  [-91.28139068693963, -39.23199699013146, -6.123102190174865, 1.561230036682851, 6.5301894935321485, 4.875730660792755, 1.5476604733551997]
# Batch_fitness 39.075765804307146
# Train_fitness 37.25379947314738
# Test_average_revenue 37.46360960052601
# u_offender 1
# u_defender 3.759999999999999
#
#
# 58
# Generation  87  : 41.01605402184754
# function_list:  [-91.18139068693964, -39.23199699013146, -6.123102190174865, 1.561230036682851, 6.5301894935321485, 4.875730660792755, 1.6476604733551998]
# Batch_fitness 41.01605402184754
# Train_fitness 37.2624465758502
# Test_average_revenue 37.47286206859438
# u_offender 1
# u_defender 3.759999999999999
#
#
# 65
# Generation  88  : 39.307814899891945
# function_list:  [-91.18139068693964, -39.031996990131454, -6.023102190174865, 1.561230036682851, 6.5301894935321485, 4.975730660792754, 1.6476604733551998]
# Batch_fitness 39.34323852711071
# Train_fitness 37.19001990031521
# Test_average_revenue 37.39777256551783
# u_offender 1
# u_defender 3.749999999999999
#
#
# 55
# Generation  89  : 39.814917204050495
# function_list:  [-91.48139068693962, -39.23199699013146, -6.123102190174865, 4.676029786523793, 6.13018949353215, 4.575730660792756, 1.5476604733551997]
# Batch_fitness 39.814917204050495
# Train_fitness 37.0072926882849
# Test_average_revenue 37.20738683762487
# u_offender 1
# u_defender 3.7
#
#
# 56
# Generation  90  : 40.38468272656354
# function_list:  [-91.48139068693962, -39.23199699013146, -6.123102190174865, 4.676029786523793, 6.13018949353215, 4.575730660792756, 1.5476604733551997]
# Batch_fitness 40.38468272656354
# Train_fitness 37.0072926882849
# Test_average_revenue 37.20738683762487
# u_offender 1
# u_defender 3.7
#
#
# 55
# Generation  91  : 39.98453150581595
# function_list:  [-91.08139068693964, -38.93199699013145, -6.123102190174865, 1.361230036682851, 6.630189493532148, 4.875730660792755, 1.5476604733551997]
# Batch_fitness 39.98453150581595
# Train_fitness 37.121753805144735
# Test_average_revenue 37.32919314757191
# u_offender 1
# u_defender 3.7199999999999998
#
#
# 58
# Generation  92  : 39.16961035217475
# function_list:  [-91.08139068693964, -38.83199699013145, -6.123102190174865, 4.676029786523793, 6.23018949353215, 4.975730660792754, 1.9476604733552]
# Batch_fitness 39.67298122470251
# Train_fitness 36.763244504120706
# Test_average_revenue 36.94944967110448
# u_offender 1
# u_defender 3.6500000000000012
#
#
# 52
# Generation  93  : 39.721471643962836
# function_list:  [-91.48139068693962, -39.031996990131454, -6.023102190174865, 1.561230036682851, 6.630189493532148, 4.875730660792755, 1.4476604733551997]
# Batch_fitness 40.565838927592694
# Train_fitness 37.11238492831955
# Test_average_revenue 37.31792819854224
# u_offender 1
# u_defender 3.71
#
#
# 59
# Generation  94  : 39.438066317879866
# function_list:  [-91.18139068693964, -39.031996990131454, -6.223102190174864, 4.676029786523793, 6.330189493532149, 4.875730660792755, 1.3476604733551996]
# Batch_fitness 39.62408899878028
# Train_fitness 36.98290268036448
# Test_average_revenue 37.178552465179635
# u_offender 1
# u_defender 3.7199999999999998
#
#
# 53
# Generation  95  : 38.763815169039525
# function_list:  [-91.28139068693963, -39.33199699013146, -6.223102190174864, 1.561230036682851, 6.330189493532149, 4.975730660792754, 1.3476604733551996]
# Batch_fitness 39.511894260568056
# Train_fitness 37.22341596366782
# Test_average_revenue 37.432540764574654
# u_offender 1
# u_defender 3.7299999999999995
#
#
# 64
# Generation  96  : 39.5096430744868
# function_list:  [-91.28139068693963, -39.33199699013146, -6.023102190174865, 1.561230036682851, 6.5301894935321485, 4.775730660792755, 1.2476604733551995]
# Batch_fitness 40.72433679386819
# Train_fitness 37.145122322701326
# Test_average_revenue 37.35134923011449
# u_offender 1
# u_defender 3.7
#
#
# 59
# Generation  97  : 39.38641763489532
# function_list:  [-91.38139068693962, -39.33199699013146, -6.023102190174865, 1.561230036682851, 6.5301894935321485, 4.775730660792755, 1.2476604733551995]
# Batch_fitness 39.38641763489532
# Train_fitness 37.15977003229341
# Test_average_revenue 37.36635278568582
# u_offender 1
# u_defender 3.71
#
#
# 48
# Generation  98  : 39.08243794867775
# function_list:  [-91.38139068693962, -39.23199699013146, -6.123102190174865, 1.361230036682851, 6.630189493532148, 4.875730660792755, 1.3476604733551996]
# Batch_fitness 39.6524339096964
# Train_fitness 37.21050212336674
# Test_average_revenue 37.4196574400586
# u_offender 1
# u_defender 3.7399999999999993
#
#
# 64
# Generation  99  : 39.055084612876755
# function_list:  [-91.58139068693961, -39.33199699013146, -6.023102190174865, 1.561230036682851, 6.330189493532149, 4.775730660792755, 1.4476604733551997]
# Batch_fitness 39.73142531768158
# Train_fitness 37.169704730078124
# Test_average_revenue 37.37739727663247
# u_offender 1
# u_defender 3.71
#
#
# Final Delay: 40.38468272656354

# %%
print(result.function_list)
# Out:
# [-91.48139068693962, -39.23199699013146, -6.123102190174865, 4.676029786523793, 6.13018949353215, 4.575730660792756, 1.5476604733551997]

# %%
xdata = np.linspace(0, 1, line_space)
ydata = func(xdata,result.function_list)
plt.plot(xdata,ydata,label='a(t)')

plt.xlabel('t')
plt.ylabel('a(t)') 
plt.title('a(t)')

plt.legend() 
plt.show()

# %%
xdata = np.linspace(0, 1, line_space)
ydata = func(xdata,result.function_list) - min(func(xdata,result.function_list))

plt.plot(xdata,ydata,label='a(t)')

plt.xlabel('t')
plt.ylabel('a(t)') 
plt.title('a(t)')

plt.legend() 
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(batch_err_list,label='Batch Data Revenue')
plt.plot(train_err_list,label='Train Data Revenue')
plt.plot(test_err_list,label='Test Data Revenue')

plt.xlabel('Generation')
plt.ylabel('Revenue') 
plt.title('Training')

plt.legend() 
plt.show()

# %%
plt.plot(batch_err_list,label='Batch Data Revenue')
plt.plot(test_err_list,label='Test Data Revenue')

plt.xlabel('Generation')
plt.ylabel('Revenue') 
plt.title('Training')

plt.legend() 
plt.show()

# %%
#plt.plot(batch_err_list,label='Batch Data Revenue')
plt.plot(test_err_list,label='Test Data Revenue')

plt.xlabel('Generation')
plt.ylabel('Revenue') 
plt.title('Training')

plt.legend() 
plt.show()

# %%
#result = best_list[len(best_list)-1]

# %%
result.debug()
# Out:
# function_list:  [-91.48139068693962, -39.23199699013146, -6.123102190174865, 4.676029786523793, 6.13018949353215, 4.575730660792756, 1.5476604733551997]
# Batch_fitness 40.38468272656354
# Train_fitness 37.0072926882849
# Test_average_revenue 37.20738683762487
# u_offender 1
# u_defender 3.7

# %%
from mpl_toolkits import mplot3d

ax = plt.axes(projection='3d')
print(result.Z_payment_list)

ax.scatter3D(X_test[:,0], X_test[:,1], result.Z_payment_list,cmap='Greens');


#ax.plot_surface(X_test[:,0], X_test[:,1], Z_payment)
ax.set_title('surface');
# Out:
# [58.34971665501942, 48.86732072597427, 63.26507021922592, 17.113663239860603, 34.07954221741146, 54.788605236708406, 0.0, 62.155733897771384, 0.0, 53.38059355750938, 64.26478532017829, 0.0, 50.66455584316679, 0.0, 66.43570499817169, 38.952510628518056, 0.0, 34.02564269722123, 46.55078827314105, 68.91012373346832, 39.68056984697522, 54.04296411030296, 51.55716467052266, 56.720724494426605, 0.0, 48.570173676715044, 51.645796736278015, 54.797527635922556, 31.458762746498437, 31.97671524504281, 1.8234427367632275, 64.68094898282226, 56.17453787312656, 44.55532629217797, 57.8928095679595, 32.70400674865556, 0.0, 47.61171096920978, 23.640518497075362, 67.78039721747126, 0.0, 0.4427012369157677, 42.434346959303646, 61.051505910473054, 0.0, 47.45754526425746, 61.66346683626234, 21.301766112251187, 35.28096361162482, 49.736206858171855, 1.6731453100352627, 36.50882274529609, 33.29002111350319, 38.45663864719732, 48.313647528354124, 29.37503375808032, 0.0, 0.0, 33.35174014430791, 51.90460864397155, 57.396811684366064, 56.154792736941474, 33.16289056867576, 32.48997276496051, 52.32950791785708, 5.1350929372642495, 51.31374965526844, 0.0, 0.0, 38.57368664402712, 0.436948973169397, 23.442033811233, 55.17499648168937, 32.05327473472856, 20.80372680440941, 54.367739038460805, 0.0, 33.245318358441125, 0.0002865056216392445, 26.890285674867602, 31.19131719299582, 23.626904709587954, 0.0, 0.0, 0.0, 0.5647943897844435, 65.21213620306166, 4.204005724117976, 38.476727318354925, 59.411415938513315, 51.059854651752275, 64.90531776779875, 48.38874913441891, 1.0269685549551744, 0.0, 0.0, 6.044433520071582, 31.413354413800207, 70.58913899976672, 32.81078646882669, 0.0, 0.0165833524919154, 48.56333222961921, 31.034338315529624, 72.15022164363347, 39.61473642192398, 16.664479777116952, 57.191837230083216, 41.003571380161176, 46.13091751884558, 66.71034845437664, 0.0, 55.72551354873777, 0.0, 26.186386253062903, 1.5632278337039138, 41.34858569293188, 29.98368077731527, 57.334598782063374, 65.58073520323035, 0.9415547267896022, 74.12382947034119, 55.00375233387656, 50.141557485610456, 42.80378512157466, 56.381392263097084, 36.4873768373523, 46.4605196373257, 71.62281153703148, 33.31983846061273, 31.79859824450314, 63.710533001635895, 36.30906091337805, 0.27660415071009437, 53.81663407035977, 0.0, 68.51413113004513, 37.686313455855895, 3.245508708375572, 42.68928952586037, 0.0, 25.61474791446787, 31.847495551372052, 66.62182923512891, 37.616712571936674, 0.0, 28.7353548147546, 0.0565910174995258, 39.92418357537521, 17.43879261420743, 59.00865022569634, 43.52880394724251, 0.0, 71.14116330175756, 34.505178918762184, 50.40859475704471, 0.0, 8.041663826014766, 56.028749526892994, 49.286102797437835, 32.56260802248325, 71.429508070884, 47.821681523996446, 54.146773762780846, 75.54338659241324, 57.35827474557715, 45.11539159627357, 10.372987042465866, 1.2838992595906589, 0.0, 51.916594417967474, 1.5940372724964473, 41.73489680032668, 72.39179034163364, 41.341599181057035, 14.687530765732198, 30.020865373741444, 32.15453804678718, 36.804713183867335, 6.861199105133482, 7.166210075514672, 2.6913862514369553, 0.0, 55.422534826596504, 71.60627919000986, 62.768916940985974, 63.87814276308031, 0.0, 30.017755127767284, 48.20230455275565, 0.0, 40.6637542019872, 65.80796586498829, 39.93145006302507, 49.52585869370933, 29.89317115350437, 38.620361413608194, 1.4153955329851249, 36.223356580452034, 59.21265740396673, 25.070123764106697, 36.38491982146839, 65.26162012126865, 36.07916511600283, 42.66113177321617, 33.949299836074246, 67.82777716755804, 47.124823558633025, 67.08107600272184, 57.10007024692128, 0.0, 53.56433228502603, 42.09075747393224, 52.51880004665403, 70.20859032401248, 29.797724514932636, 32.26427388193419, 42.54861174675228, 4.703153691591434, 33.29500014159679, 0.35973115986674836, 14.020259110654381, 46.20301886199262, 47.93542274426627, 60.40552732172005, 31.884732955982656, 15.215538259863244, 31.549315818337078, 67.60145687560583, 43.36443334032218, 31. ...

# %%
fig = plt.figure()
contour = plt.tricontourf(X_test[:,1],  X_test[:,0], result.Z_payment_list
              
               #cmap = cm.get_cmap(name='jet')
                         )
fig.colorbar(contour)
plt.title('payment')
plt.xlabel(r"Defender type $\dot{\Theta}$d")
plt.ylabel(r"offender type $\dot{\Theta}$o")

fig.savefig('3D.png')
plt.show()

# %%
from scipy.interpolate import griddata
grid_x, grid_y = np.mgrid[0:15:400j, 400:0:400j]
points =np.reshape([X_test[:,1],X_test[:,0]],(2,-1))
points = np.transpose(points)
grid_z0 = griddata(points, result.Z_payment_list, (grid_x, grid_y), method='nearest')
im =plt.imshow(grid_z0.T, extent=(0,15,0,400) , aspect='auto',interpolation='bilinear')
plt.colorbar(im)
plt.title('payment')
plt.xlabel(r"Defender type $\dot{\Theta}$d")
plt.ylabel(r"offender type $\dot{\Theta}$o")
plt.show()

# %%
grid_x, grid_y = np.mgrid[0:15:400j, 400:0:400j]

points =np.reshape([X_test[:,1],X_test[:,0]],(2,-1))

points = np.transpose(points)

grid_z1 = griddata(points, result.Z_o_star_list, (grid_x, grid_y), method='nearest')


im =plt.imshow(grid_z1.T, extent=(0,15,0,400) , aspect='auto',interpolation='bilinear')
plt.colorbar(im)
plt.title('t*')
plt.xlabel(r"Defender type $\dot{\Theta}$d")
plt.ylabel(r"offender type $\dot{\Theta}$o")
plt.show()
